# %%
def generate_action_4(name, prefix, first=True):
    if first:
        return f"""
    action {name}(bit<32> in01, bit<32> in02, bit<32> in03, bit<32> in04) {{
        {prefix}.l32_1 = in01;
        {prefix}.l32_2 = in02;
        {prefix}.l32_3 = in03;
        {prefix}.l32_4 = in04;
    }}
    """
    else:
        return f"""
    action {name}(bit<32> in01, bit<32> in02, bit<32> in03, bit<32> in04) {{
        {prefix}.l32_1 = in01 + {prefix}.l32_1;
        {prefix}.l32_2 = in02 + {prefix}.l32_2;
        {prefix}.l32_3 = in03 + {prefix}.l32_3;
        {prefix}.l32_4 = in04 + {prefix}.l32_4;
    }}
    """

def generate_action_8(name, prefix, first=True):
    if first:
        return f"""
    action {name}(bit<32> in01, bit<32> in02, bit<32> in03, bit<32> in04,
                bit<32> in05, bit<32> in06, bit<32> in07, bit<32> in08) {{
        {prefix}.l32_1 = in01;
        {prefix}.l32_2 = in02;
        {prefix}.l32_3 = in03;
        {prefix}.l32_4 = in04;
        {prefix}.l32_5 = in05;
        {prefix}.l32_6 = in06;
        {prefix}.l32_7 = in07;
        {prefix}.l32_8 = in08;
    }}
    """
    else:
        return f"""
    action {name}(bit<32> in01, bit<32> in02, bit<32> in03, bit<32> in04,
                bit<32> in05, bit<32> in06, bit<32> in07, bit<32> in08) {{
        {prefix}.l32_1 = in01 + {prefix}.l32_1;
        {prefix}.l32_2 = in02 + {prefix}.l32_2;
        {prefix}.l32_3 = in03 + {prefix}.l32_3;
        {prefix}.l32_4 = in04 + {prefix}.l32_4;
        {prefix}.l32_5 = in05 + {prefix}.l32_5;
        {prefix}.l32_6 = in06 + {prefix}.l32_6;
        {prefix}.l32_7 = in07 + {prefix}.l32_7;
        {prefix}.l32_8 = in08 + {prefix}.l32_8;
    }}
    """

def generate_action_12(name, prefix0, prefix1, first=True):
    if first:
        return f"""
    action {name}(bit<32> in01, bit<32> in02, bit<32> in03, bit<32> in04,
                bit<32> in05, bit<32> in06, bit<32> in07, bit<32> in08,
                bit<32> in11, bit<32> in12, bit<32> in13, bit<32> in14) {{
        {prefix0}.l32_1 = in01;
        {prefix0}.l32_2 = in02;
        {prefix0}.l32_3 = in03;
        {prefix0}.l32_4 = in04;
        {prefix0}.l32_5 = in05;
        {prefix0}.l32_6 = in06;
        {prefix0}.l32_7 = in07;
        {prefix0}.l32_8 = in08;

        {prefix1}.l32_1 = in11;
        {prefix1}.l32_2 = in12;
        {prefix1}.l32_3 = in13;
        {prefix1}.l32_4 = in14;
    }}
    """
    else:
        return f"""
    action {name}(bit<32> in01, bit<32> in02, bit<32> in03, bit<32> in04,
                bit<32> in05, bit<32> in06, bit<32> in07, bit<32> in08,
                bit<32> in11, bit<32> in12, bit<32> in13, bit<32> in14) {{
        {prefix0}.l32_1 = in01 + {prefix0}.l32_1;
        {prefix0}.l32_2 = in02 + {prefix0}.l32_2;
        {prefix0}.l32_3 = in03 + {prefix0}.l32_3;
        {prefix0}.l32_4 = in04 + {prefix0}.l32_4;
        {prefix0}.l32_5 = in05 + {prefix0}.l32_5;
        {prefix0}.l32_6 = in06 + {prefix0}.l32_6;
        {prefix0}.l32_7 = in07 + {prefix0}.l32_7;
        {prefix0}.l32_8 = in08 + {prefix0}.l32_8;

        {prefix1}.l32_1 = in11 + {prefix1}.l32_1;
        {prefix1}.l32_2 = in12 + {prefix1}.l32_2;
        {prefix1}.l32_3 = in13 + {prefix1}.l32_3;
        {prefix1}.l32_4 = in14 + {prefix1}.l32_4;
    }}
    """

def generate_action_16(name, prefix0, prefix1, first=True):
    if first:
        return f"""
    action {name}(bit<32> in01, bit<32> in02, bit<32> in03, bit<32> in04,
                bit<32> in05, bit<32> in06, bit<32> in07, bit<32> in08,
                bit<32> in11, bit<32> in12, bit<32> in13, bit<32> in14,
                bit<32> in15, bit<32> in16, bit<32> in17, bit<32> in18) {{
        {prefix0}.l32_1 = in01;
        {prefix0}.l32_2 = in02;
        {prefix0}.l32_3 = in03;
        {prefix0}.l32_4 = in04;
        {prefix0}.l32_5 = in05;
        {prefix0}.l32_6 = in06;
        {prefix0}.l32_7 = in07;
        {prefix0}.l32_8 = in08;

        {prefix1}.l32_1 = in11;
        {prefix1}.l32_2 = in12;
        {prefix1}.l32_3 = in13;
        {prefix1}.l32_4 = in14;
        {prefix1}.l32_5 = in15;
        {prefix1}.l32_6 = in16;
        {prefix1}.l32_7 = in17;
        {prefix1}.l32_8 = in18;
    }}
    """
    else:
        return f"""
    action {name}(bit<32> in01, bit<32> in02, bit<32> in03, bit<32> in04,
                bit<32> in05, bit<32> in06, bit<32> in07, bit<32> in08,
                bit<32> in11, bit<32> in12, bit<32> in13, bit<32> in14,
                bit<32> in15, bit<32> in16, bit<32> in17, bit<32> in18) {{
        {prefix0}.l32_1 = in01 + {prefix0}.l32_1;
        {prefix0}.l32_2 = in02 + {prefix0}.l32_2;
        {prefix0}.l32_3 = in03 + {prefix0}.l32_3;
        {prefix0}.l32_4 = in04 + {prefix0}.l32_4;
        {prefix0}.l32_5 = in05 + {prefix0}.l32_5;
        {prefix0}.l32_6 = in06 + {prefix0}.l32_6;
        {prefix0}.l32_7 = in07 + {prefix0}.l32_7;
        {prefix0}.l32_8 = in08 + {prefix0}.l32_8;

        {prefix1}.l32_1 = in11 + {prefix1}.l32_1;
        {prefix1}.l32_2 = in12 + {prefix1}.l32_2;
        {prefix1}.l32_3 = in13 + {prefix1}.l32_3;
        {prefix1}.l32_4 = in14 + {prefix1}.l32_4;
        {prefix1}.l32_5 = in15 + {prefix1}.l32_5;
        {prefix1}.l32_6 = in16 + {prefix1}.l32_6;
        {prefix1}.l32_7 = in17 + {prefix1}.l32_7;
        {prefix1}.l32_8 = in18 + {prefix1}.l32_8;
    }}
    """
    
def generate_action_24(name, prefix0, prefix1, prefix2, first=True):
    if first:
        return f"""
    action {name}(bit<32> in01, bit<32> in02, bit<32> in03, bit<32> in04,
                bit<32> in05, bit<32> in06, bit<32> in07, bit<32> in08,
                bit<32> in11, bit<32> in12, bit<32> in13, bit<32> in14,
                bit<32> in15, bit<32> in16, bit<32> in17, bit<32> in18,
                bit<32> in21, bit<32> in22, bit<32> in23, bit<32> in24,
                bit<32> in25, bit<32> in26, bit<32> in27, bit<32> in28) {{
        {prefix0}.l32_1 = in01;
        {prefix0}.l32_2 = in02;
        {prefix0}.l32_3 = in03;
        {prefix0}.l32_4 = in04;
        {prefix0}.l32_5 = in05;
        {prefix0}.l32_6 = in06;
        {prefix0}.l32_7 = in07;
        {prefix0}.l32_8 = in08;

        {prefix1}.l32_1 = in11;
        {prefix1}.l32_2 = in12;
        {prefix1}.l32_3 = in13;
        {prefix1}.l32_4 = in14;
        {prefix1}.l32_5 = in15;
        {prefix1}.l32_6 = in16;
        {prefix1}.l32_7 = in17;
        {prefix1}.l32_8 = in18;

        {prefix2}.l32_1 = in21;
        {prefix2}.l32_2 = in22;
        {prefix2}.l32_3 = in23;
        {prefix2}.l32_4 = in24;
        {prefix2}.l32_5 = in25;
        {prefix2}.l32_6 = in26;
        {prefix2}.l32_7 = in27;
        {prefix2}.l32_8 = in28;
    }}
    """
    else:
        return f"""
    action {name}(bit<32> in01, bit<32> in02, bit<32> in03, bit<32> in04,
                bit<32> in05, bit<32> in06, bit<32> in07, bit<32> in08,
                bit<32> in11, bit<32> in12, bit<32> in13, bit<32> in14,
                bit<32> in15, bit<32> in16, bit<32> in17, bit<32> in18,
                bit<32> in21, bit<32> in22, bit<32> in23, bit<32> in24,
                bit<32> in25, bit<32> in26, bit<32> in27, bit<32> in28) {{
        {prefix0}.l32_1 = in01 + {prefix0}.l32_1;
        {prefix0}.l32_2 = in02 + {prefix0}.l32_2;
        {prefix0}.l32_3 = in03 + {prefix0}.l32_3;
        {prefix0}.l32_4 = in04 + {prefix0}.l32_4;
        {prefix0}.l32_5 = in05 + {prefix0}.l32_5;
        {prefix0}.l32_6 = in06 + {prefix0}.l32_6;
        {prefix0}.l32_7 = in07 + {prefix0}.l32_7;
        {prefix0}.l32_8 = in08 + {prefix0}.l32_8;

        {prefix1}.l32_1 = in11 + {prefix1}.l32_1;
        {prefix1}.l32_2 = in12 + {prefix1}.l32_2;
        {prefix1}.l32_3 = in13 + {prefix1}.l32_3;
        {prefix1}.l32_4 = in14 + {prefix1}.l32_4;
        {prefix1}.l32_5 = in15 + {prefix1}.l32_5;
        {prefix1}.l32_6 = in16 + {prefix1}.l32_6;
        {prefix1}.l32_7 = in17 + {prefix1}.l32_7;
        {prefix1}.l32_8 = in18 + {prefix1}.l32_8;
        
        {prefix2}.l32_1 = in21 + {prefix2}.l32_1;
        {prefix2}.l32_2 = in22 + {prefix2}.l32_2;
        {prefix2}.l32_3 = in23 + {prefix2}.l32_3;
        {prefix2}.l32_4 = in24 + {prefix2}.l32_4;
        {prefix2}.l32_5 = in25 + {prefix2}.l32_5;
        {prefix2}.l32_6 = in26 + {prefix2}.l32_6;
        {prefix2}.l32_7 = in27 + {prefix2}.l32_7;
        {prefix2}.l32_8 = in28 + {prefix2}.l32_8;
    }}
    """


def generate_action_1(name, prefix, first=True, bit=32):
    if first:
        return f"""
    action {name}(bit<{bit}> in01) {{
        {prefix} = in01;
    }}
    """
    else:
        return f"""
    action {name}(bit<{bit}> in01) {{
        {prefix} = in01 + {prefix};
    }}
    """

def generate_table(name, key, action, stage, type="ternary", table_size="1024"):
    if len(key) == 1:
        return f"""
    @stage ({stage})
    table {name} {{
        key = {{
            {key[0]}: {type};
        }}
        actions = {{
            {action};
            noaction;
        }}
        size = {table_size};
        default_action = noaction();
        idle_timeout = false;
    }}
    """
    elif len(key) == 2:
        return f"""
    @stage ({stage})
    table {name} {{
        key = {{
            {key[0]}: {type};
            {key[1]}: {type};
        }}
        actions = {{
            {action};
            noaction;
        }}
        size = {table_size};
        default_action = noaction();
        idle_timeout = false;
    }}
    """
    elif len(key) == 3:
        return f"""
    @stage ({stage})
    table {name} {{
        key = {{
            {key[0]}: {type};
            {key[1]}: {type};
            {key[2]}: {type};
        }}
        actions = {{
            {action};
            noaction;
        }}
        size = {table_size};
        default_action = noaction();
        idle_timeout = false;
    }}
    """

# %%
def generate_action_cnn(name, lists, nums):
    cnn_outputs = []
    for num in range(len(nums)):
        for i in range(len(lists)):
            for j in range(lists[i][0], lists[i][1] + 1):
                cnn_outputs.append(f"ig_md.cnn_{nums[num]}_{i+1}.l16_{j}")

    ins = ""
    inputs = []
    outputs = ''
    for i in range(len(cnn_outputs)):
        inputs.append(f"in{i}")
        if i != 0:
            ins = ins + ', '
        ins = ins + f'bit<16> in{i}'
        outputs += f'\t\t{cnn_outputs[i]} = in{i} + {cnn_outputs[i]};\n'

    return f"""
    action {name}({ins}) {{
{outputs}
    }}
    """

# %%
def generate_p4():
    tables = [
        ("x1_1_2"  , ["hdr.feature.x_1.l16_1" ], "set_x1_1_2"  , 0),
        ("x1_3_4"  , ["hdr.feature.x_1.l16_1" ], "set_x1_3_4"  , 0),
        ("x8_1_2"  , ["hdr.feature.x_8.l16_1" ], "set_x8_1_2"  , 0),
        ("x8_3_4"  , ["hdr.feature.x_8.l16_1" ], "set_x8_3_4"  , 0),
        ("x2_1_2"  , ["hdr.feature.x_2.l16_1" ], "set_x2_1_2"  , 1),
        ("x2_3_4"  , ["hdr.feature.x_2.l16_1" ], "set_x2_3_4"  , 1),
        ("x7_1_2"  , ["hdr.feature.x_7.l16_1" ], "set_x7_1_2"  , 1),
        ("x7_3_4"  , ["hdr.feature.x_7.l16_1" ], "set_x7_3_4"  , 1),
        ("x3_1_2"  , ["hdr.feature.x_3.l16_1" ], "set_x3_1_2"  , 2),
        ("x3_3_4"  , ["hdr.feature.x_3.l16_1" ], "set_x3_3_4"  , 2),
        ("x4_1_2"  , ["hdr.feature.x_4.l16_1" ], "set_x4_1_2"  , 3),
        ("x4_3_4"  , ["hdr.feature.x_4.l16_1" ], "set_x4_3_4"  , 3),
        ("x5_1_2"  , ["hdr.feature.x_5.l16_1" ], "set_x5_1_2"  , 4),
        ("x5_3_4"  , ["hdr.feature.x_5.l16_1" ], "set_x5_3_4"  , 4),
        ("x6_1_2"  , ["hdr.feature.x_6.l16_1" ], "set_x6_1_2"  , 5),
        ("x6_3_4"  , ["hdr.feature.x_6.l16_1" ], "set_x6_3_4"  , 5),
    ]

    actions = [
        ("set_x1_1_2"   , "ig_md.temp.l4_1" , True),
        ("set_x1_3_4"   , "ig_md.temp.l4_2" , True),
        ("set_x2_1_2"   , "ig_md.temp.l4_3" , True),
        ("set_x2_3_4"   , "ig_md.temp.l4_4" , True),
        ("set_x3_1_2"   , "ig_md.temp.l4_5" , True),
        ("set_x3_3_4"   , "ig_md.temp.l4_6" , True),
        ("set_x4_1_2"   , "ig_md.temp.l4_7" , True),
        ("set_x4_3_4"   , "ig_md.temp.l4_8" , True),
        ("set_x5_1_2"   , "ig_md.temp.l4_9" , True),
        ("set_x5_3_4"   , "ig_md.temp.l4_10", True),
        ("set_x6_1_2"   , "ig_md.temp.l4_11", True),
        ("set_x6_3_4"   , "ig_md.temp.l4_12", True),
        ("set_x7_1_2"   , "ig_md.temp.l4_13", True),
        ("set_x7_3_4"   , "ig_md.temp.l4_14", True),
        ("set_x8_1_2"   , "ig_md.temp.l4_15", True),
        ("set_x8_3_4"   , "ig_md.temp.l4_16", True),
    ]

    p4_code = ""

    for name, prefix0, first in actions:
        p4_code += generate_action_1(name, prefix0, first, bit=4)
    base_stage = 0
    for name, key, action, stage in tables:
        p4_code += generate_table(name, key, action, base_stage + stage)
    return p4_code

with open("generated_code.p4", "w") as f:
    f.write(generate_p4())

# %%
def generate_p4():
    tables = [
        ("x1_1_4"  , ["ig_md.temp.l4_1",  "ig_md.temp.l4_2"] , "set_x1_1_4"  , 1, "exact", 256),
        ("x2_1_4"  , ["ig_md.temp.l4_3",  "ig_md.temp.l4_4"] , "set_x2_1_4"  , 2, "exact", 256),
        ("x3_1_4"  , ["ig_md.temp.l4_5",  "ig_md.temp.l4_6"] , "set_x3_1_4"  , 3, "exact", 256),
        ("x4_1_4"  , ["ig_md.temp.l4_7",  "ig_md.temp.l4_8"] , "set_x4_1_4"  , 4, "exact", 256),
        ("x5_1_4"  , ["ig_md.temp.l4_9",  "ig_md.temp.l4_10"], "set_x5_1_4"  , 5, "exact", 256),
        ("x6_1_4"  , ["ig_md.temp.l4_11", "ig_md.temp.l4_12"], "set_x6_1_4"  , 6, "exact", 256),
        ("x7_1_4"  , ["ig_md.temp.l4_13", "ig_md.temp.l4_14"], "set_x7_1_4"  , 2, "exact", 256),
        ("x8_1_4"  , ["ig_md.temp.l4_15", "ig_md.temp.l4_16"], "set_x8_1_4"  , 1, "exact", 256),
    ]

    actions = [
        ("set_x1_1_4", [[1,1],[1,1],[1,1]], [1]),
        ("set_x2_1_4", [[1,2],[1,2],[1,2]], [1]),
        ("set_x3_1_4", [[1,3],[1,3],[1,3]], [1]),
        ("set_x4_1_4", [[2,4],[1,4],[1,4]], [1]),
        ("set_x5_1_4", [[3,5],[2,5],[1,4]], [1]),
        ("set_x6_1_4", [[4,6],[3,5],[2,4]], [1]),
        ("set_x7_1_4", [[5,6],[4,5],[3,4]], [1]),
        ("set_x8_1_4", [[6,6],[5,5],[4,4]], [1]),
    ]

    p4_code = ""

    for name, lists, nums in actions:
        p4_code += generate_action_cnn(name, lists, nums)
    base_stage = 0
    for name, key, action, stage, match_type, table_size in tables:
        p4_code += generate_table(name, key, action, base_stage + stage, match_type, table_size)
    return p4_code

with open("generated_code.p4", "w") as f:
    f.write(generate_p4())

# %%
def generate_p4():
    tables = [
        ("cnn_1_1_1_2"  , ["ig_md.cnn_1_1.l16_1", "ig_md.cnn_1_1.l16_2" ], "set_cnn_1_1_1_2"  , 0),
        ("cnn_1_1_3_4"  , ["ig_md.cnn_1_1.l16_3", "ig_md.cnn_1_1.l16_4" ], "set_cnn_1_1_3_4"  , 0),

        ("cnn_1_1_5_6"  , ["ig_md.cnn_1_1.l16_5", "ig_md.cnn_1_1.l16_6" ], "set_cnn_1_1_5_6"  , 1),

        ("cnn_1_2_1_2"  , ["ig_md.cnn_1_2.l16_1", "ig_md.cnn_1_2.l16_2" ], "set_cnn_1_2_1_2"  , 1),
        ("cnn_1_2_3_4"  , ["ig_md.cnn_1_2.l16_3", "ig_md.cnn_1_2.l16_4" ], "set_cnn_1_2_3_4"  , 2),
        ("cnn_1_2_5"    , ["ig_md.cnn_1_2.l16_5"], "set_cnn_1_2_5"  , 2),

        ("cnn_1_3_1_2"  , ["ig_md.cnn_1_3.l16_1", "ig_md.cnn_1_3.l16_2" ], "set_cnn_1_3_1_2"  , 3),
        ("cnn_1_3_3_4"  , ["ig_md.cnn_1_3.l16_3", "ig_md.cnn_1_3.l16_4" ], "set_cnn_1_3_3_4"  , 3),

    ]

    actions = [
        ("set_cnn_1_1_1_2"   , "hdr.output.linear1" , True),
        ("set_cnn_1_1_3_4"   , "ig_md.linear1" , True),

        ("set_cnn_1_1_5_6"   , "hdr.output.linear1" , False),

        ("set_cnn_1_2_1_2"   , "ig_md.linear1" , False),

        ("set_cnn_1_2_3_4"   , "hdr.output.linear1" , False),
        ("set_cnn_1_2_5"     , "ig_md.linear1" , False),

        ("set_cnn_1_3_1_2"   , "hdr.output.linear1", False),
        ("set_cnn_1_3_3_4"   , "ig_md.linear1", False),
    ]

    p4_code = ""

    for name, prefix0, first in actions:
        p4_code += generate_action_4(name, prefix0, first)
    base_stage = 7
    for name, key, action, stage in tables:
        p4_code += generate_table(name, key, action, base_stage + stage)
    return p4_code

with open("generated_code.p4", "w") as f:
    f.write(generate_p4())
